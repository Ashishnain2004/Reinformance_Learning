# %%
import tensorflow.compat.v1 as tf  # TensorFlow v1 compatibility for v2, use "import tensorflow as tf" in v1

tf.disable_v2_behavior()  # disable TensorFlow v2. Delete if using v1
import cv2  # read in pixel data
import snake  # game class
import numpy as np
import random
import os
from collections import (
    deque,
)  # queue data structure. fast appends. and pops. replay memory
from numpy.random import choice  # to choose based on a probability
# Out:
# WARNING:tensorflow:From d:\Python\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Hyperparameters

USE_MODEL = False  # False = training, True = testing

ACTIONS = 5  # up, down, left, right, stay
GAMMA = 0.99  # learning rate

# Initial and final epsilon to balance exploration/exploitation
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 0.05
EXPLORE = 10000  # how many frames until final epsilon is reached
OBSERVE = 1000  # how many frames to observe at training start

SAVE_STEP = 5000  # how many steps until save checkpoint
REPLAY_MEMORY = 200000  # store our experiences, the size of it

IMG_SIZE = 60  # images size to train on
BATCH = 64  # batch size to train on

# %%
# Create TensorFlow graph
def createGraph():
    """
    Network Architecture:

    Layer   Input       Filter size Stride  Num filters Activation	Output
    conv1   60x60x4     6×6	            4   32          ReLU        15x15x32
    pool1   15x15x32    2×2	            2                           8x8x32
    conv2   8x8x32      4×4	            2   64          ReLU        4x4x64
    conv3   4x4x64      3×3	            1   64          ReLU        4x4x64
    fc4     4x4x64                          512         ReLU        512
    fc5     512                             ACTIONS     Linear      ACTIONS

    """

    W_conv1 = tf.Variable(tf.truncated_normal([6, 6, 4, 32], stddev=0.02))
    b_conv1 = tf.Variable(tf.constant(0.01, shape=[32]))

    W_conv2 = tf.Variable(tf.truncated_normal([4, 4, 32, 64], stddev=0.02))
    b_conv2 = tf.Variable(tf.constant(0.01, shape=[64]))

    W_conv3 = tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.02))
    b_conv3 = tf.Variable(tf.constant(0.01, shape=[64]))

    W_fc4 = tf.Variable(tf.truncated_normal([1024, 512], stddev=0.02))
    b_fc4 = tf.Variable(tf.constant(0.01, shape=[512]))

    W_fc5 = tf.Variable(tf.truncated_normal([512, ACTIONS], stddev=0.02))
    b_fc5 = tf.Variable(tf.constant(0.01, shape=[ACTIONS]))

    # input for pixel data
    s = tf.placeholder("float", [None, IMG_SIZE, IMG_SIZE, 4])

    conv1 = tf.nn.relu(
        tf.nn.conv2d(s, W_conv1, strides=[1, 4, 4, 1], padding="SAME") + b_conv1
    )

    pool1 = tf.nn.max_pool(
        conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="SAME"
    )

    conv2 = tf.nn.relu(
        tf.nn.conv2d(pool1, W_conv2, strides=[1, 2, 2, 1], padding="SAME") + b_conv2
    )

    conv3 = tf.nn.relu(
        tf.nn.conv2d(conv2, W_conv3, strides=[1, 1, 1, 1], padding="SAME") + b_conv3
    )

    conv3_flat = tf.reshape(conv3, [-1, 1024])

    fc4 = tf.nn.relu(tf.matmul(conv3_flat, W_fc4) + b_fc4)

    fc5 = tf.matmul(fc4, W_fc5) + b_fc5

    return s, fc5

# %%
# Train deep q network. feed in pixel data to graph session
def trainGraph(inp, out):

    # to calculate the argmax, we multiply the predicted output with a vector with one value 1 and rest as 0
    argmax = tf.placeholder("float", [None, ACTIONS])
    gt = tf.placeholder("float", [None])  # ground truth
    global_step = tf.Variable(0, name="global_step")

    # action
    action = tf.reduce_sum(tf.multiply(out, argmax), reduction_indices=1)
    # cost function we will reduce through backpropagation
    cost = tf.reduce_mean(tf.square(action - gt))
    # optimization function to minimize our cost function
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # initialize our game
    game = snake.SnakeGame()

    # create a queue for experience replay to store policies
    D = deque()

    # intial frame
    frame = game.GetPresentFrame()
    # convert rgb to gray scale for processing
    frame = cv2.cvtColor(cv2.resize(frame, (IMG_SIZE, IMG_SIZE)), cv2.COLOR_BGR2GRAY)
    # binary colors, black or white
    ret, frame = cv2.threshold(frame, 1, 255, cv2.THRESH_BINARY)
    # stack frames, that is our input tensor
    inp_t = np.stack((frame, frame, frame, frame), axis=2)

    saver = tf.train.Saver(tf.global_variables())

    sess = tf.InteractiveSession(config=tf.ConfigProto(log_device_placement=True))

    # restore latest checkpoint or initialize a new graph
    checkpoint = tf.train.latest_checkpoint("./checkpoints")
    if checkpoint != None:
        print("Restore Checkpoint %s" % (checkpoint))
        saver.restore(sess, checkpoint)
        print("Model restored.")
    else:
        init = tf.global_variables_initializer()
        sess.run(init)
        print("Initialized new Graph")

    t = global_step.eval()
    c = 0

    epsilon = INITIAL_EPSILON

    # Training time
    while 1:
        # output tensor
        out_t = out.eval(feed_dict={inp: [inp_t]})[0]
        # argmax function
        argmax_t = np.zeros([ACTIONS])

        # exploration or exploitation
        if random.random() <= epsilon and not USE_MODEL:
            # make 0 the most choosen action for realistic randomness
            maxIndex = choice((0, 1, 2, 3, 4), 1, p=(0.80, 0.05, 0.05, 0.05, 0.05))
        else:
            maxIndex = np.argmax(out_t)
        argmax_t[maxIndex] = 1

        if epsilon > FINAL_EPSILON:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        mode = "observing"
        if t > OBSERVE:
            mode = "training"
        if USE_MODEL:
            mode = "model only"

        # move game forward by one frame, get reward and frame
        reward_t, frame = game.GetNextFrame(argmax_t, [t, np.max(out_t), epsilon, mode])
        # get frame pixel data
        frame = cv2.cvtColor(
            cv2.resize(frame, (IMG_SIZE, IMG_SIZE)), cv2.COLOR_BGR2GRAY
        )
        ret, frame = cv2.threshold(frame, 1, 255, cv2.THRESH_BINARY)
        frame = np.reshape(frame, (IMG_SIZE, IMG_SIZE, 1))
        # new input tensor
        inp_t1 = np.append(frame, inp_t[:, :, 0:3], axis=2)

        # add our input tensor, argmax tensor, reward and updated input tensor to replay memory
        D.append((inp_t, argmax_t, reward_t, inp_t1))

        # if we run out of replay memory, make room
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        # training iteration
        if c > OBSERVE and not USE_MODEL:

            # get random sample from our replay memory
            minibatch = random.sample(D, BATCH)

            inp_batch = [d[0] for d in minibatch]
            argmax_batch = [d[1] for d in minibatch]
            reward_batch = [d[2] for d in minibatch]
            inp_t1_batch = [d[3] for d in minibatch]

            gt_batch = []
            out_batch = out.eval(feed_dict={inp: inp_t1_batch})

            # add values to our batch
            for i in range(0, len(minibatch)):
                gt_batch.append(reward_batch[i] + GAMMA * np.max(out_batch[i]))

            # train on that
            train_step.run(
                feed_dict={gt: gt_batch, argmax: argmax_batch, inp: inp_batch}
            )

        # update our input tensor the the next frame
        inp_t = inp_t1
        t = t + 1
        c = c + 1

        # print our where we are after saving where we are
        if t % SAVE_STEP == 0 and not USE_MODEL:
            sess.run(global_step.assign(t))
            saver.save(sess, "./checkpoints/model.ckpt", global_step=t)

        print(
            "TIMESTEP",
            t,
            "/ EPSILON",
            epsilon,
            "/ ACTION",
            maxIndex,
            "/ REWARD",
            reward_t,
            "/ Q_MAX %e" % np.max(out_t),
        )

# %%
if not os.path.exists('./checkpoints'):
    os.makedirs('./checkpoints')
#input layer and output layer by creating graph
inp, out = createGraph()

# %%
# train our graph on input and output with session variables
trainGraph(inp, out)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
#
# Restore Checkpoint ./checkpoints\model.ckpt-1930000
# INFO:tensorflow:Restoring parameters from ./checkpoints\model.ckpt-1930000
# Model restored.
# TIMESTEP 1930001 / EPSILON 0.999905 / ACTION [0] / REWARD 0 / Q_MAX 1.225804e+00
# TIMESTEP 1930002 / EPSILON 0.9998100000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.376794e+00
# TIMESTEP 1930003 / EPSILON 0.9997150000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.293372e+00
# TIMESTEP 1930004 / EPSILON 0.9996200000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.343323e+00
# TIMESTEP 1930005 / EPSILON 0.9995250000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.360647e+00
# TIMESTEP 1930006 / EPSILON 0.9994300000000003 / ACTION [0] / REWARD 0 / Q_MAX 1.368833e+00
# TIMESTEP 1930007 / EPSILON 0.9993350000000003 / ACTION [0] / REWARD 0 / Q_MAX 1.377966e+00
# TIMESTEP 1930008 / EPSILON 0.9992400000000004 / ACTION [0] / REWARD 0 / Q_MAX 1.386711e+00
# TIMESTEP 1930009 / EPSILON 0.9991450000000004 / ACTION [0] / REWARD 0 / Q_MAX 1.342305e+00
# TIMESTEP 1930010 / EPSILON 0.9990500000000004 / ACTION [0] / REWARD 0 / Q_MAX 1.221892e+00
# TIMESTEP 1930011 / EPSILON 0.9989550000000005 / ACTION [0] / REWARD 0 / Q_MAX 1.216744e+00
# TIMESTEP 1930012 / EPSILON 0.9988600000000005 / ACTION [0] / REWARD 0 / Q_MAX 1.263394e+00
# TIMESTEP 1930013 / EPSILON 0.9987650000000006 / ACTION [0] / REWARD 0 / Q_MAX 1.226836e+00
# TIMESTEP 1930014 / EPSILON 0.9986700000000006 / ACTION [1] / REWARD 0 / Q_MAX 1.221169e+00
# TIMESTEP 1930015 / EPSILON 0.9985750000000007 / ACTION [0] / REWARD 0 / Q_MAX 1.164723e+00
# TIMESTEP 1930016 / EPSILON 0.9984800000000007 / ACTION [0] / REWARD 0 / Q_MAX 1.152557e+00
# TIMESTEP 1930017 / EPSILON 0.9983850000000007 / ACTION [0] / REWARD 0 / Q_MAX 1.126271e+00
# TIMESTEP 1930018 / EPSILON 0.9982900000000008 / ACTION [0] / REWARD 0 / Q_MAX 1.073601e+00
# TIMESTEP 1930019 / EPSILON 0.9981950000000008 / ACTION [0] / REWARD -1 / Q_MAX 9.635611e-01
# TIMESTEP 1930020 / EPSILON 0.9981000000000009 / ACTION [0] / REWARD 0 / Q_MAX 1.208404e+00
# TIMESTEP 1930021 / EPSILON 0.9980050000000009 / ACTION [0] / REWARD 0 / Q_MAX 1.094867e+00
# TIMESTEP 1930022 / EPSILON 0.997910000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.140256e+00
# TIMESTEP 1930023 / EPSILON 0.997815000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.115402e+00
# TIMESTEP 1930024 / EPSILON 0.997720000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.109239e+00
# TIMESTEP 1930025 / EPSILON 0.9976250000000011 / ACTION [0] / REWARD 0 / Q_MAX 1.082814e+00
# TIMESTEP 1930026 / EPSILON 0.9975300000000011 / ACTION [0] / REWARD 0 / Q_MAX 1.071712e+00
# TIMESTEP 1930027 / EPSILON 0.9974350000000012 / ACTION [0] / REWARD 0 / Q_MAX 9.991776e-01
# TIMESTEP 1930028 / EPSILON 0.9973400000000012 / ACTION [0] / REWARD 0 / Q_MAX 9.772148e-01
# TIMESTEP 1930029 / EPSILON 0.9972450000000013 / ACTION [0] / REWARD 0 / Q_MAX 1.004577e+00
# TIMESTEP 1930030 / EPSILON 0.9971500000000013 / ACTION [0] / REWARD 0 / Q_MAX 9.726676e-01
# TIMESTEP 1930031 / EPSILON 0.9970550000000014 / ACTION [0] / REWARD 0 / Q_MAX 1.037493e+00
# TIMESTEP 1930032 / EPSILON 0.9969600000000014 / ACTION [0] / REWARD 0 / Q_MAX 1.006201e+00
# TIMESTEP 1930033 / EPSILON 0.9968650000000014 / ACTION [0] / REWARD 0 / Q_MAX 9.456994e-01
# TIMESTEP 1930034 / EPSILON 0.9967700000000015 / ACTION [0] / REWARD 0 / Q_MAX 9.817713e-01
# TIMESTEP 1930035 / EPSILON 0.9966750000000015 / ACTION [0] / REWARD 0 / Q_MAX 9.270865e-01
# TIMESTEP 1930036 / EPSILON 0.9965800000000016 / ACTION [0] / REWARD 0 / Q_MAX 8.720646e-01
# TIMESTEP 1930037 / EPSILON 0.9964850000000016 / ACTION [0] / REWARD -1 / Q_MAX 6.867926e-01
# TIMESTEP 1930038 / EPSILON 0.9963900000000017 / ACTION [0] / REWARD 0 / Q_MAX 1.121526e+00
# TIMESTEP 1930039 / EPSILON 0.9962950000000017 / ACTION [0] / REWARD 0 / Q_MAX 1.089342e+00
# TIMESTEP 1930040 / EPSILON 0.9962000000000018 / ACTION [0] / REWARD 0 / Q_MAX 1.143657e+00
# TIMESTEP 1930041 / EPSILON 0.9961050000000018 / ACTION [0] / REWARD 0 / Q_MAX 1.212369e+00
# TIMESTEP 1930042 / EPSILON 0.9960100000000018 / ACTION [4] / REWARD 0 / Q_MAX 1.276039e+00
# TIMESTEP 1930043 / EPSILON 0.9959150000000019 / ACTION [0] / REWARD 0 / Q_MAX 1.164822e+00
# TIMESTEP 1930044 / EPSILON 0.9958200000000019 / ACTION [0] / REWARD 0 / Q_MAX 1.158864e+00
# TIMESTEP 1930045 / EPSILON 0.995725000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.159005e+00
# TIMESTEP 1930046 / EPSILON 0.995630000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.148174e+00
# TIMESTEP 1930047 / EPSILON 0.9955350000000021 / ACTION [0] / REWARD 0 / Q_MAX 1.118006e+00
# TIMESTEP 1930048 / EPSILON 0.9954400000000021 / ACTION [0] / REWARD 0 / Q_MAX 9.907004e-01
# TIMESTEP 1930049 / EPSILON 0.9953450000000021 / ACTION [1] / REWARD 0 / Q_MAX 1.057561e+00
# TIMESTEP 1930050 / EPSILON 0.9952500000000022 / ACTION [0] / REWARD 0 / Q_MAX 1.050905e+00
# TIMESTEP 1930051 / EPSILON 0.9951550000000022 / ACTION [0] / REWARD 0 / Q_MAX 9.761878e-01
# TIMESTEP 1930052 / EPSILON 0.9950600000000023 / ACTION [0] / REWARD 0 / Q_MAX 9.936619e-01
# TIMESTEP 1930053 / EPSILON 0.9949650000000023 / ACTION [0] / REWARD 0 / Q_MAX 1.017581e+00
# TIMESTEP 1930054 / EPSILON 0.9948700000000024 / ACTION [0] / REWARD 0 / Q_MAX 9.910812e-01
# TIMESTEP 1930055 / EPSILON 0.9947750000000024 / ACTION [2] / REWARD 0 / Q_MAX 1.010097e+00
# TIMESTEP 1930056 / EPSILON 0.9946800000000025 / ACTION [0] / REWARD 0 / Q_MAX 9.601734e-01
# TIMESTEP 1930057 / EPSILON 0.9945850000000025 / ACTION [0] / REWARD 0 / Q_MAX 9.751034e-01
# TIMESTEP 1930058 / EPSILON 0.9944900000000025 / ACTION [0] / REWARD 0 / Q_MAX 9.581981e-01
# TIMESTEP 1930059 / EPSILON 0.9943950000000026 / ACTION [0] / REWARD 0 / Q_MAX 9.658533e-01
# TIMESTEP 1930060 / EPSILON 0.9943000000000026 / ACTION [0] / REWARD 0 / Q_MAX 9.801766e-01
# TIMESTEP 1930061 / EPSILON 0.9942050000000027 / ACTION [0] / REWARD 0 / Q_MAX 9.533693e-01
# TIMESTEP 1930062 / EPSILON 0.9941100000000027 / ACTION [0] / REWARD 0 / Q_MAX 9.203758e-01
# TIMESTEP 1930063 / EPSILON 0.9940150000000028 / ACTION [0] / REWARD -1 / Q_MAX 8.615603e-01
# TIMESTEP 1930115 / EPSILON 0.989075000000005 / ACTION [4] / REWARD 0 / Q_MAX 9.537638e-01
# TIMESTEP 1930116 / EPSILON 0.9889800000000051 / ACTION [0] / REWARD 0 / Q_MAX 9.656524e-01
# TIMESTEP 1930117 / EPSILON 0.9888850000000051 / ACTION [0] / REWARD 0 / Q_MAX 9.182253e-01
# TIMESTEP 1930118 / EPSILON 0.9887900000000052 / ACTION [0] / REWARD 0 / Q_MAX 8.917828e-01
# TIMESTEP 1930119 / EPSILON 0.9886950000000052 / ACTION [0] / REWARD 0 / Q_MAX 8.820606e-01
# TIMESTEP 1930120 / EPSILON 0.9886000000000053 / ACTION [0] / REWARD 0 / Q_MAX 8.764323e-01
# TIMESTEP 1930121 / EPSILON 0.9885050000000053 / ACTION 1 / REWARD 0 / Q_MAX 8.919573e-01
# TIMESTEP 1930122 / EPSILON 0.9884100000000053 / ACTION [0] / REWARD 0 / Q_MAX 9.522364e-01
# TIMESTEP 1930123 / EPSILON 0.9883150000000054 / ACTION [0] / REWARD 0 / Q_MAX 9.868889e-01
# TIMESTEP 1930124 / EPSILON 0.9882200000000054 / ACTION [0] / REWARD 0 / Q_MAX 8.967897e-01
# TIMESTEP 1930125 / EPSILON 0.9881250000000055 / ACTION 1 / REWARD 0 / Q_MAX 9.057074e-01
# TIMESTEP 1930126 / EPSILON 0.9880300000000055 / ACTION [0] / REWARD 0 / Q_MAX 9.274504e-01
# TIMESTEP 1930127 / EPSILON 0.9879350000000056 / ACTION [2] / REWARD 0 / Q_MAX 9.250956e-01
# TIMESTEP 1930128 / EPSILON 0.9878400000000056 / ACTION [0] / REWARD 0 / Q_MAX 1.002037e+00
# TIMESTEP 1930129 / EPSILON 0.9877450000000056 / ACTION [2] / REWARD 0 / Q_MAX 1.008348e+00
# TIMESTEP 1930130 / EPSILON 0.9876500000000057 / ACTION [0] / REWARD 0 / Q_MAX 9.938361e-01
# TIMESTEP 1930131 / EPSILON 0.9875550000000057 / ACTION [0] / REWARD 0 / Q_MAX 1.021993e+00
# TIMESTEP 1930132 / EPSILON 0.9874600000000058 / ACTION [0] / REWARD 0 / Q_MAX 1.030779e+00
# TIMESTEP 1930133 / EPSILON 0.9873650000000058 / ACTION [4] / REWARD 0 / Q_MAX 1.028941e+00
# TIMESTEP 1930134 / EPSILON 0.9872700000000059 / ACTION [1] / REWARD 0 / Q_MAX 9.072346e-01
# TIMESTEP 1930135 / EPSILON 0.9871750000000059 / ACTION [1] / REWARD 0 / Q_MAX 9.059256e-01
# TIMESTEP 1930136 / EPSILON 0.987080000000006 / ACTION [0] / REWARD 0 / Q_MAX 1.004061e+00
# TIMESTEP 1930137 / EPSILON 0.986985000000006 / ACTION [0] / REWARD 0 / Q_MAX 9.904848e-01
# TIMESTEP 1930138 / EPSILON 0.986890000000006 / ACTION [0] / REWARD 0 / Q_MAX 9.603580e-01
# TIMESTEP 1930139 / EPSILON 0.9867950000000061 / ACTION [0] / REWARD 0 / Q_MAX 9.627181e-01
# TIMESTEP 1930140 / EPSILON 0.9867000000000061 / ACTION [0] / REWARD 0 / Q_MAX 9.288574e-01
# TIMESTEP 1930141 / EPSILON 0.9866050000000062 / ACTION [0] / REWARD 0 / Q_MAX 9.152492e-01
# TIMESTEP 1930142 / EPSILON 0.9865100000000062 / ACTION [0] / REWARD 0 / Q_MAX 9.613474e-01
# TIMESTEP 1930143 / EPSILON 0.9864150000000063 / ACTION [0] / REWARD 0 / Q_MAX 9.994463e-01
# TIMESTEP 1930144 / EPSILON 0.9863200000000063 / ACTION [4] / REWARD -1 / Q_MAX 9.950461e-01
# TIMESTEP 1930145 / EPSILON 0.9862250000000063 / ACTION 2 / REWARD 0 / Q_MAX 1.112186e+00
# TIMESTEP 1930146 / EPSILON 0.9861300000000064 / ACTION [1] / REWARD 0 / Q_MAX 1.241904e+00
# TIMESTEP 1930147 / EPSILON 0.9860350000000064 / ACTION [0] / REWARD 0 / Q_MAX 1.218710e+00
# TIMESTEP 1930148 / EPSILON 0.9859400000000065 / ACTION [0] / REWARD 0 / Q_MAX 1.273307e+00
# TIMESTEP 1930149 / EPSILON 0.9858450000000065 / ACTION [2] / REWARD 0 / Q_MAX 1.330455e+00
# TIMESTEP 1930150 / EPSILON 0.9857500000000066 / ACTION [0] / REWARD 0 / Q_MAX 1.281552e+00
# TIMESTEP 1930151 / EPSILON 0.9856550000000066 / ACTION [0] / REWARD 0 / Q_MAX 1.257081e+00
# TIMESTEP 1930152 / EPSILON 0.9855600000000067 / ACTION [3] / REWARD 0 / Q_MAX 1.268653e+00
# TIMESTEP 1930153 / EPSILON 0.9854650000000067 / ACTION [0] / REWARD 0 / Q_MAX 1.314546e+00
# TIMESTEP 1930154 / EPSILON 0.9853700000000067 / ACTION [0] / REWARD 0 / Q_MAX 1.337176e+00
# TIMESTEP 1930155 / EPSILON 0.9852750000000068 / ACTION [1] / REWARD 0 / Q_MAX 1.234033e+00
# TIMESTEP 1930156 / EPSILON 0.9851800000000068 / ACTION [0] / REWARD 0 / Q_MAX 1.158703e+00
# TIMESTEP 1930157 / EPSILON 0.9850850000000069 / ACTION 0 / REWARD 0 / Q_MAX 1.167669e+00
# TIMESTEP 1930158 / EPSILON 0.9849900000000069 / ACTION [0] / REWARD 0 / Q_MAX 1.181624e+00
# TIMESTEP 1930159 / EPSILON 0.984895000000007 / ACTION [4] / REWARD 0 / Q_MAX 1.168786e+00
# TIMESTEP 1930160 / EPSILON 0.984800000000007 / ACTION [1] / REWARD 0 / Q_MAX 1.103222e+00
# TIMESTEP 1930161 / EPSILON 0.984705000000007 / ACTION [0] / REWARD 0 / Q_MAX 1.094602e+00
# TIMESTEP 1930162 / EPSILON 0.9846100000000071 / ACTION [0] / REWARD 0 / Q_MAX 1.086612e+00
# TIMESTEP 1930163 / EPSILON 0.9845150000000071 / ACTION [3] / REWARD 0 / Q_MAX 1.072997e+00
# TIMESTEP 1930164 / EPSILON 0.9844200000000072 / ACTION [0] / REWARD 0 / Q_MAX 1.055400e+00
# TIMESTEP 1930165 / EPSILON 0.9843250000000072 / ACTION [0] / REWARD 0 / Q_MAX 1.012815e+00
# TIMESTEP 1930166 / EPSILON 0.9842300000000073 / ACTION [0] / REWARD 0 / Q_MAX 1.018065e+00
# TIMESTEP 1930167 / EPSILON 0.9841350000000073 / ACTION [3] / REWARD 0 / Q_MAX 1.022454e+00
# TIMESTEP 1930168 / EPSILON 0.9840400000000074 / ACTION [0] / REWARD 0 / Q_MAX 1.021731e+00
# TIMESTEP 1930169 / EPSILON 0.9839450000000074 / ACTION [4] / REWARD 0 / Q_MAX 9.743167e-01
# TIMESTEP 1930170 / EPSILON 0.9838500000000074 / ACTION [0] / REWARD 0 / Q_MAX 1.046766e+00
# TIMESTEP 1930171 / EPSILON 0.9837550000000075 / ACTION [0] / REWARD 0 / Q_MAX 1.030276e+00
# TIMESTEP 1930172 / EPSILON 0.9836600000000075 / ACTION [0] / REWARD 0 / Q_MAX 1.050651e+00
# TIMESTEP 1930173 / EPSILON 0.9835650000000076 / ACTION [0] / REWARD 0 / Q_MAX 1.010995e+00
# TIMESTEP 1930174 / EPSILON 0.9834700000000076 / ACTION [0] / REWARD 0 / Q_MAX 1.089740e+00
# TIMESTEP 1930175 / EPSILON 0.9833750000000077 / ACTION [0] / REWARD 0 / Q_MAX 1.138711e+00
# TIMESTEP 1930176 / EPSILON 0.9832800000000077 / ACTION [0] / REWARD 0 / Q_MAX 1.093578e+00
# TIMESTEP 1930177 / EPSILON 0.9831850000000077 / ACTION [3] / REWARD 0 / Q_MAX 1.048688e+00
# TIMESTEP 1930178 / EPSILON 0.9830900000000078 / ACTION [0] / REWARD 0 / Q_MAX 9.698526e-01
# TIMESTEP 1930179 / EPSILON 0.9829950000000078 / ACTION [4] / REWARD -1 / Q_MAX 9.264874e-01
# TIMESTEP 1930180 / EPSILON 0.9829000000000079 / ACTION [0] / REWARD 0 / Q_MAX 1.222034e+00
# TIMESTEP 1930181 / EPSILON 0.9828050000000079 / ACTION [0] / REWARD 0 / Q_MAX 1.261477e+00
# TIMESTEP 1930182 / EPSILON 0.982710000000008 / ACTION [0] / REWARD 0 / Q_MAX 1.245382e+00
# TIMESTEP 1930183 / EPSILON 0.982615000000008 / ACTION [0] / REWARD 0 / Q_MAX 1.254602e+00
# TIMESTEP 1930184 / EPSILON 0.982520000000008 / ACTION [1] / REWARD 0 / Q_MAX 1.253368e+00
# TIMESTEP 1930185 / EPSILON 0.9824250000000081 / ACTION [0] / REWARD 0 / Q_MAX 1.205812e+00
# TIMESTEP 1930186 / EPSILON 0.9823300000000081 / ACTION [0] / REWARD 0 / Q_MAX 1.213938e+00
# TIMESTEP 1930187 / EPSILON 0.9822350000000082 / ACTION [3] / REWARD 0 / Q_MAX 1.210649e+00
# TIMESTEP 1930188 / EPSILON 0.9821400000000082 / ACTION [0] / REWARD 0 / Q_MAX 1.150267e+00
# TIMESTEP 1930189 / EPSILON 0.9820450000000083 / ACTION [0] / REWARD 0 / Q_MAX 1.223462e+00
# TIMESTEP 1930190 / EPSILON 0.9819500000000083 / ACTION [0] / REWARD 0 / Q_MAX 1.136522e+00
# TIMESTEP 1930191 / EPSILON 0.9818550000000084 / ACTION [0] / REWARD 0 / Q_MAX 1.122009e+00
# TIMESTEP 1930218 / EPSILON 0.9792900000000095 / ACTION [0] / REWARD 0 / Q_MAX 1.200420e+00
# TIMESTEP 1930219 / EPSILON 0.9791950000000096 / ACTION [0] / REWARD 0 / Q_MAX 1.231571e+00
# TIMESTEP 1930220 / EPSILON 0.9791000000000096 / ACTION 0 / REWARD 0 / Q_MAX 1.273596e+00
# TIMESTEP 1930221 / EPSILON 0.9790050000000097 / ACTION [1] / REWARD 0 / Q_MAX 1.276620e+00
# TIMESTEP 1930222 / EPSILON 0.9789100000000097 / ACTION 0 / REWARD 0 / Q_MAX 1.232838e+00
# TIMESTEP 1930223 / EPSILON 0.9788150000000098 / ACTION [0] / REWARD 0 / Q_MAX 1.207998e+00
# TIMESTEP 1930224 / EPSILON 0.9787200000000098 / ACTION [0] / REWARD 0 / Q_MAX 1.163506e+00
# TIMESTEP 1930225 / EPSILON 0.9786250000000098 / ACTION [3] / REWARD 0 / Q_MAX 1.148801e+00
# TIMESTEP 1930226 / EPSILON 0.9785300000000099 / ACTION [0] / REWARD 0 / Q_MAX 1.259383e+00
# TIMESTEP 1930227 / EPSILON 0.9784350000000099 / ACTION [0] / REWARD 0 / Q_MAX 1.256717e+00
# TIMESTEP 1930228 / EPSILON 0.97834000000001 / ACTION [0] / REWARD 0 / Q_MAX 1.202188e+00
# TIMESTEP 1930229 / EPSILON 0.97824500000001 / ACTION [0] / REWARD 0 / Q_MAX 1.240472e+00
# TIMESTEP 1930230 / EPSILON 0.9781500000000101 / ACTION [0] / REWARD 0 / Q_MAX 1.274359e+00
# TIMESTEP 1930231 / EPSILON 0.9780550000000101 / ACTION [0] / REWARD 0 / Q_MAX 1.299541e+00
# TIMESTEP 1930232 / EPSILON 0.9779600000000102 / ACTION [0] / REWARD 0 / Q_MAX 1.290589e+00
# TIMESTEP 1930233 / EPSILON 0.9778650000000102 / ACTION [0] / REWARD 0 / Q_MAX 1.331677e+00
# TIMESTEP 1930234 / EPSILON 0.9777700000000102 / ACTION [0] / REWARD 0 / Q_MAX 1.389668e+00
# TIMESTEP 1930235 / EPSILON 0.9776750000000103 / ACTION [0] / REWARD 0 / Q_MAX 1.405439e+00
# TIMESTEP 1930236 / EPSILON 0.9775800000000103 / ACTION [0] / REWARD 0 / Q_MAX 1.333832e+00
# TIMESTEP 1930237 / EPSILON 0.9774850000000104 / ACTION [3] / REWARD 0 / Q_MAX 1.318100e+00
# TIMESTEP 1930238 / EPSILON 0.9773900000000104 / ACTION [0] / REWARD 0 / Q_MAX 1.287798e+00
# TIMESTEP 1930239 / EPSILON 0.9772950000000105 / ACTION [4] / REWARD 0 / Q_MAX 1.267842e+00
# TIMESTEP 1930240 / EPSILON 0.9772000000000105 / ACTION [0] / REWARD 0 / Q_MAX 1.331655e+00
# TIMESTEP 1930241 / EPSILON 0.9771050000000105 / ACTION [3] / REWARD 0 / Q_MAX 1.303487e+00
# TIMESTEP 1930242 / EPSILON 0.9770100000000106 / ACTION [0] / REWARD 0 / Q_MAX 1.225742e+00
# TIMESTEP 1930269 / EPSILON 0.9744450000000118 / ACTION [0] / REWARD 0 / Q_MAX 1.241576e+00
# TIMESTEP 1930270 / EPSILON 0.9743500000000118 / ACTION [0] / REWARD -1 / Q_MAX 1.133929e+00
# TIMESTEP 1930271 / EPSILON 0.9742550000000119 / ACTION [0] / REWARD 0 / Q_MAX 1.263923e+00
# TIMESTEP 1930272 / EPSILON 0.9741600000000119 / ACTION [0] / REWARD 0 / Q_MAX 1.192738e+00
# TIMESTEP 1930273 / EPSILON 0.974065000000012 / ACTION [0] / REWARD 0 / Q_MAX 1.189975e+00
# TIMESTEP 1930274 / EPSILON 0.973970000000012 / ACTION [0] / REWARD 0 / Q_MAX 1.228712e+00
# TIMESTEP 1930275 / EPSILON 0.973875000000012 / ACTION [0] / REWARD 0 / Q_MAX 1.191335e+00
# TIMESTEP 1930276 / EPSILON 0.9737800000000121 / ACTION [1] / REWARD 0 / Q_MAX 1.254192e+00
# TIMESTEP 1930277 / EPSILON 0.9736850000000121 / ACTION [0] / REWARD 0 / Q_MAX 1.295102e+00
# TIMESTEP 1930278 / EPSILON 0.9735900000000122 / ACTION [0] / REWARD 0 / Q_MAX 1.311217e+00
# TIMESTEP 1930279 / EPSILON 0.9734950000000122 / ACTION [3] / REWARD 0 / Q_MAX 1.239971e+00
# TIMESTEP 1930280 / EPSILON 0.9734000000000123 / ACTION [1] / REWARD 0 / Q_MAX 1.249928e+00
# TIMESTEP 1930281 / EPSILON 0.9733050000000123 / ACTION [3] / REWARD 0 / Q_MAX 1.312455e+00
# TIMESTEP 1930282 / EPSILON 0.9732100000000123 / ACTION 4 / REWARD 0 / Q_MAX 1.283034e+00
# TIMESTEP 1930283 / EPSILON 0.9731150000000124 / ACTION [0] / REWARD 0 / Q_MAX 1.291879e+00
# TIMESTEP 1930284 / EPSILON 0.9730200000000124 / ACTION [0] / REWARD 0 / Q_MAX 1.283582e+00
# TIMESTEP 1930285 / EPSILON 0.9729250000000125 / ACTION 3 / REWARD 0 / Q_MAX 1.213832e+00
# TIMESTEP 1930286 / EPSILON 0.9728300000000125 / ACTION 3 / REWARD 0 / Q_MAX 1.227131e+00
# TIMESTEP 1930287 / EPSILON 0.9727350000000126 / ACTION [0] / REWARD 0 / Q_MAX 1.264229e+00
# TIMESTEP 1930288 / EPSILON 0.9726400000000126 / ACTION [0] / REWARD 0 / Q_MAX 1.211379e+00
# TIMESTEP 1930289 / EPSILON 0.9725450000000126 / ACTION [0] / REWARD 0 / Q_MAX 1.298288e+00
# TIMESTEP 1930290 / EPSILON 0.9724500000000127 / ACTION 2 / REWARD 0 / Q_MAX 1.248530e+00
# TIMESTEP 1930291 / EPSILON 0.9723550000000127 / ACTION [0] / REWARD 0 / Q_MAX 1.303372e+00
# TIMESTEP 1930292 / EPSILON 0.9722600000000128 / ACTION [4] / REWARD 0 / Q_MAX 1.298503e+00
# TIMESTEP 1930293 / EPSILON 0.9721650000000128 / ACTION [0] / REWARD 0 / Q_MAX 1.266548e+00
# TIMESTEP 1930294 / EPSILON 0.9720700000000129 / ACTION [0] / REWARD 0 / Q_MAX 1.285240e+00
# TIMESTEP 1930295 / EPSILON 0.9719750000000129 / ACTION [0] / REWARD 0 / Q_MAX 1.228073e+00
# TIMESTEP 1930296 / EPSILON 0.971880000000013 / ACTION [0] / REWARD 0 / Q_MAX 1.204293e+00
# TIMESTEP 1930297 / EPSILON 0.971785000000013 / ACTION [0] / REWARD 0 / Q_MAX 1.209093e+00
# TIMESTEP 1930298 / EPSILON 0.971690000000013 / ACTION [0] / REWARD 0 / Q_MAX 1.272795e+00
# TIMESTEP 1930299 / EPSILON 0.9715950000000131 / ACTION [2] / REWARD 0 / Q_MAX 1.262376e+00
# TIMESTEP 1930300 / EPSILON 0.9715000000000131 / ACTION [0] / REWARD 0 / Q_MAX 1.204667e+00
# TIMESTEP 1930301 / EPSILON 0.9714050000000132 / ACTION [0] / REWARD 0 / Q_MAX 1.244357e+00
# TIMESTEP 1930302 / EPSILON 0.9713100000000132 / ACTION [0] / REWARD 0 / Q_MAX 1.229305e+00
# TIMESTEP 1930303 / EPSILON 0.9712150000000133 / ACTION [2] / REWARD 0 / Q_MAX 1.304675e+00
# TIMESTEP 1930304 / EPSILON 0.9711200000000133 / ACTION [0] / REWARD 0 / Q_MAX 1.283246e+00
# TIMESTEP 1930305 / EPSILON 0.9710250000000133 / ACTION [0] / REWARD 0 / Q_MAX 1.234220e+00
# TIMESTEP 1930306 / EPSILON 0.9709300000000134 / ACTION [0] / REWARD 0 / Q_MAX 1.255818e+00
# TIMESTEP 1930307 / EPSILON 0.9708350000000134 / ACTION [0] / REWARD 0 / Q_MAX 1.241829e+00
# TIMESTEP 1930308 / EPSILON 0.9707400000000135 / ACTION [2] / REWARD 0 / Q_MAX 1.217471e+00
# TIMESTEP 1930309 / EPSILON 0.9706450000000135 / ACTION [4] / REWARD 0 / Q_MAX 1.234092e+00
# TIMESTEP 1930310 / EPSILON 0.9705500000000136 / ACTION [0] / REWARD 0 / Q_MAX 1.300974e+00
# TIMESTEP 1930311 / EPSILON 0.9704550000000136 / ACTION [3] / REWARD 0 / Q_MAX 1.310533e+00
# TIMESTEP 1930312 / EPSILON 0.9703600000000137 / ACTION [1] / REWARD 0 / Q_MAX 1.345639e+00
# TIMESTEP 1930313 / EPSILON 0.9702650000000137 / ACTION [2] / REWARD 0 / Q_MAX 1.283772e+00
# TIMESTEP 1930314 / EPSILON 0.9701700000000137 / ACTION [0] / REWARD 0 / Q_MAX 1.234370e+00
# TIMESTEP 1930315 / EPSILON 0.9700750000000138 / ACTION [0] / REWARD 0 / Q_MAX 1.200632e+00
# TIMESTEP 1930316 / EPSILON 0.9699800000000138 / ACTION 0 / REWARD 0 / Q_MAX 1.206362e+00
# TIMESTEP 1930317 / EPSILON 0.9698850000000139 / ACTION [0] / REWARD 0 / Q_MAX 1.203257e+00
# TIMESTEP 1930318 / EPSILON 0.9697900000000139 / ACTION [0] / REWARD 0 / Q_MAX 1.243806e+00
# TIMESTEP 1930319 / EPSILON 0.969695000000014 / ACTION [0] / REWARD 0 / Q_MAX 1.232841e+00
# TIMESTEP 1930320 / EPSILON 0.969600000000014 / ACTION [0] / REWARD 0 / Q_MAX 1.233952e+00
# TIMESTEP 1930321 / EPSILON 0.969505000000014 / ACTION [0] / REWARD 0 / Q_MAX 1.258806e+00
# TIMESTEP 1930322 / EPSILON 0.9694100000000141 / ACTION [3] / REWARD 0 / Q_MAX 1.237538e+00
# TIMESTEP 1930323 / EPSILON 0.9693150000000141 / ACTION [1] / REWARD 0 / Q_MAX 1.244413e+00
# TIMESTEP 1930324 / EPSILON 0.9692200000000142 / ACTION [0] / REWARD 0 / Q_MAX 1.282843e+00
# TIMESTEP 1930325 / EPSILON 0.9691250000000142 / ACTION [0] / REWARD 0 / Q_MAX 1.281349e+00
# TIMESTEP 1930326 / EPSILON 0.9690300000000143 / ACTION [0] / REWARD 0 / Q_MAX 1.249109e+00
# TIMESTEP 1930327 / EPSILON 0.9689350000000143 / ACTION [0] / REWARD 0 / Q_MAX 1.246774e+00
# TIMESTEP 1930328 / EPSILON 0.9688400000000144 / ACTION [0] / REWARD 0 / Q_MAX 1.273791e+00
# TIMESTEP 1930329 / EPSILON 0.9687450000000144 / ACTION [0] / REWARD 0 / Q_MAX 1.267980e+00
# TIMESTEP 1930330 / EPSILON 0.9686500000000144 / ACTION [4] / REWARD 0 / Q_MAX 1.203677e+00
# TIMESTEP 1930331 / EPSILON 0.9685550000000145 / ACTION [0] / REWARD 0 / Q_MAX 1.248110e+00
# TIMESTEP 1930332 / EPSILON 0.9684600000000145 / ACTION [0] / REWARD 0 / Q_MAX 1.180440e+00
# TIMESTEP 1930333 / EPSILON 0.9683650000000146 / ACTION [2] / REWARD 0 / Q_MAX 1.206884e+00
# TIMESTEP 1930334 / EPSILON 0.9682700000000146 / ACTION [0] / REWARD 0 / Q_MAX 1.221599e+00
# TIMESTEP 1930335 / EPSILON 0.9681750000000147 / ACTION [0] / REWARD 0 / Q_MAX 1.295501e+00
# TIMESTEP 1930336 / EPSILON 0.9680800000000147 / ACTION 4 / REWARD 0 / Q_MAX 1.245342e+00
# TIMESTEP 1930337 / EPSILON 0.9679850000000148 / ACTION [0] / REWARD 0 / Q_MAX 1.226010e+00
# TIMESTEP 1930338 / EPSILON 0.9678900000000148 / ACTION [0] / REWARD 0 / Q_MAX 1.329762e+00
# TIMESTEP 1930339 / EPSILON 0.9677950000000148 / ACTION [1] / REWARD 0 / Q_MAX 1.304754e+00
# TIMESTEP 1930340 / EPSILON 0.9677000000000149 / ACTION [0] / REWARD 0 / Q_MAX 1.296021e+00
# TIMESTEP 1930341 / EPSILON 0.9676050000000149 / ACTION [3] / REWARD 0 / Q_MAX 1.302306e+00
# TIMESTEP 1930342 / EPSILON 0.967510000000015 / ACTION [0] / REWARD 0 / Q_MAX 1.243378e+00
# TIMESTEP 1930343 / EPSILON 0.967415000000015 / ACTION [0] / REWARD 0 / Q_MAX 1.146451e+00
# TIMESTEP 1930344 / EPSILON 0.9673200000000151 / ACTION [0] / REWARD 0 / Q_MAX 1.147212e+00
# TIMESTEP 1930371 / EPSILON 0.9647550000000162 / ACTION [0] / REWARD 0 / Q_MAX 1.158872e+00
# TIMESTEP 1930372 / EPSILON 0.9646600000000163 / ACTION [2] / REWARD 0 / Q_MAX 1.130209e+00
# TIMESTEP 1930373 / EPSILON 0.9645650000000163 / ACTION [0] / REWARD 0 / Q_MAX 1.155858e+00
# TIMESTEP 1930374 / EPSILON 0.9644700000000164 / ACTION [0] / REWARD 0 / Q_MAX 1.153758e+00
# TIMESTEP 1930375 / EPSILON 0.9643750000000164 / ACTION [0] / REWARD 0 / Q_MAX 1.192012e+00
# TIMESTEP 1930376 / EPSILON 0.9642800000000165 / ACTION [1] / REWARD 0 / Q_MAX 1.174077e+00
# TIMESTEP 1930377 / EPSILON 0.9641850000000165 / ACTION [0] / REWARD 0 / Q_MAX 1.142968e+00
# TIMESTEP 1930378 / EPSILON 0.9640900000000165 / ACTION [0] / REWARD 0 / Q_MAX 1.181177e+00
# TIMESTEP 1930379 / EPSILON 0.9639950000000166 / ACTION [0] / REWARD 0 / Q_MAX 1.202971e+00
# TIMESTEP 1930380 / EPSILON 0.9639000000000166 / ACTION [3] / REWARD 0 / Q_MAX 1.197474e+00
# TIMESTEP 1930381 / EPSILON 0.9638050000000167 / ACTION [0] / REWARD 0 / Q_MAX 1.168688e+00
# TIMESTEP 1930382 / EPSILON 0.9637100000000167 / ACTION [0] / REWARD 0 / Q_MAX 1.255091e+00
# TIMESTEP 1930383 / EPSILON 0.9636150000000168 / ACTION [0] / REWARD 0 / Q_MAX 1.255220e+00
# TIMESTEP 1930384 / EPSILON 0.9635200000000168 / ACTION [0] / REWARD 0 / Q_MAX 1.307582e+00
# TIMESTEP 1930385 / EPSILON 0.9634250000000169 / ACTION [0] / REWARD 0 / Q_MAX 1.328666e+00
# TIMESTEP 1930386 / EPSILON 0.9633300000000169 / ACTION [0] / REWARD 0 / Q_MAX 1.264302e+00
# TIMESTEP 1930387 / EPSILON 0.9632350000000169 / ACTION [3] / REWARD 0 / Q_MAX 1.271489e+00
# TIMESTEP 1930388 / EPSILON 0.963140000000017 / ACTION [0] / REWARD 0 / Q_MAX 1.284623e+00
# TIMESTEP 1930389 / EPSILON 0.963045000000017 / ACTION [0] / REWARD 0 / Q_MAX 1.295457e+00
# TIMESTEP 1930390 / EPSILON 0.9629500000000171 / ACTION [2] / REWARD 0 / Q_MAX 1.304662e+00
# TIMESTEP 1930391 / EPSILON 0.9628550000000171 / ACTION [0] / REWARD 0 / Q_MAX 1.365618e+00
# TIMESTEP 1930392 / EPSILON 0.9627600000000172 / ACTION [0] / REWARD 0 / Q_MAX 1.406719e+00
# TIMESTEP 1930393 / EPSILON 0.9626650000000172 / ACTION [0] / REWARD 0 / Q_MAX 1.284007e+00
# TIMESTEP 1930394 / EPSILON 0.9625700000000172 / ACTION [0] / REWARD 0 / Q_MAX 1.304757e+00
# TIMESTEP 1930395 / EPSILON 0.9624750000000173 / ACTION [0] / REWARD 0 / Q_MAX 1.284215e+00
# TIMESTEP 1930422 / EPSILON 0.9599100000000185 / ACTION [0] / REWARD 0 / Q_MAX 1.195557e+00
# TIMESTEP 1930423 / EPSILON 0.9598150000000185 / ACTION [0] / REWARD 0 / Q_MAX 1.175123e+00
# TIMESTEP 1930424 / EPSILON 0.9597200000000186 / ACTION [0] / REWARD 0 / Q_MAX 1.158868e+00
# TIMESTEP 1930425 / EPSILON 0.9596250000000186 / ACTION [0] / REWARD 0 / Q_MAX 1.206546e+00
# TIMESTEP 1930426 / EPSILON 0.9595300000000186 / ACTION [0] / REWARD 0 / Q_MAX 1.118444e+00
# TIMESTEP 1930427 / EPSILON 0.9594350000000187 / ACTION [2] / REWARD 0 / Q_MAX 1.033262e+00
# TIMESTEP 1930428 / EPSILON 0.9593400000000187 / ACTION [0] / REWARD 0 / Q_MAX 1.042876e+00
# TIMESTEP 1930429 / EPSILON 0.9592450000000188 / ACTION [0] / REWARD 0 / Q_MAX 1.064740e+00
# TIMESTEP 1930430 / EPSILON 0.9591500000000188 / ACTION [0] / REWARD 0 / Q_MAX 1.038004e+00
# TIMESTEP 1930431 / EPSILON 0.9590550000000189 / ACTION 2 / REWARD 0 / Q_MAX 1.056016e+00
# TIMESTEP 1930432 / EPSILON 0.9589600000000189 / ACTION 3 / REWARD 0 / Q_MAX 1.045525e+00
# TIMESTEP 1930433 / EPSILON 0.958865000000019 / ACTION [0] / REWARD 0 / Q_MAX 1.028649e+00
# TIMESTEP 1930434 / EPSILON 0.958770000000019 / ACTION [0] / REWARD 0 / Q_MAX 1.027709e+00
# TIMESTEP 1930435 / EPSILON 0.958675000000019 / ACTION [0] / REWARD 0 / Q_MAX 9.739818e-01
# TIMESTEP 1930436 / EPSILON 0.9585800000000191 / ACTION [0] / REWARD 0 / Q_MAX 9.649524e-01
# TIMESTEP 1930437 / EPSILON 0.9584850000000191 / ACTION 4 / REWARD 0 / Q_MAX 9.056245e-01
# TIMESTEP 1930438 / EPSILON 0.9583900000000192 / ACTION [2] / REWARD 0 / Q_MAX 1.001191e+00
# TIMESTEP 1930439 / EPSILON 0.9582950000000192 / ACTION [0] / REWARD 0 / Q_MAX 9.859194e-01
# TIMESTEP 1930440 / EPSILON 0.9582000000000193 / ACTION [0] / REWARD 0 / Q_MAX 1.023239e+00
# TIMESTEP 1930441 / EPSILON 0.9581050000000193 / ACTION [0] / REWARD 0 / Q_MAX 9.425428e-01
# TIMESTEP 1930442 / EPSILON 0.9580100000000193 / ACTION 2 / REWARD 0 / Q_MAX 9.773743e-01
# TIMESTEP 1930443 / EPSILON 0.9579150000000194 / ACTION [0] / REWARD 0 / Q_MAX 1.085901e+00
# TIMESTEP 1930444 / EPSILON 0.9578200000000194 / ACTION [2] / REWARD 0 / Q_MAX 1.124411e+00
# TIMESTEP 1930445 / EPSILON 0.9577250000000195 / ACTION [0] / REWARD 0 / Q_MAX 1.208016e+00
# TIMESTEP 1930446 / EPSILON 0.9576300000000195 / ACTION [0] / REWARD 0 / Q_MAX 1.221306e+00
# TIMESTEP 1930447 / EPSILON 0.9575350000000196 / ACTION [3] / REWARD 0 / Q_MAX 1.213222e+00
# TIMESTEP 1930448 / EPSILON 0.9574400000000196 / ACTION 2 / REWARD 0 / Q_MAX 1.185306e+00
# TIMESTEP 1930449 / EPSILON 0.9573450000000197 / ACTION [1] / REWARD 0 / Q_MAX 1.225250e+00
# TIMESTEP 1930450 / EPSILON 0.9572500000000197 / ACTION [0] / REWARD 0 / Q_MAX 1.233966e+00
# TIMESTEP 1930451 / EPSILON 0.9571550000000197 / ACTION [0] / REWARD 0 / Q_MAX 1.120994e+00
# TIMESTEP 1930452 / EPSILON 0.9570600000000198 / ACTION [0] / REWARD 0 / Q_MAX 1.157376e+00
# TIMESTEP 1930453 / EPSILON 0.9569650000000198 / ACTION [0] / REWARD 0 / Q_MAX 1.179196e+00
# TIMESTEP 1930454 / EPSILON 0.9568700000000199 / ACTION [3] / REWARD 0 / Q_MAX 1.080867e+00
# TIMESTEP 1930455 / EPSILON 0.9567750000000199 / ACTION [2] / REWARD 0 / Q_MAX 1.045844e+00
# TIMESTEP 1930456 / EPSILON 0.95668000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.080585e+00
# TIMESTEP 1930457 / EPSILON 0.95658500000002 / ACTION 3 / REWARD 0 / Q_MAX 1.109277e+00
# TIMESTEP 1930458 / EPSILON 0.95649000000002 / ACTION [0] / REWARD 0 / Q_MAX 1.129307e+00
# TIMESTEP 1930459 / EPSILON 0.9563950000000201 / ACTION [1] / REWARD 0 / Q_MAX 1.096582e+00
# TIMESTEP 1930460 / EPSILON 0.9563000000000201 / ACTION [0] / REWARD 0 / Q_MAX 1.192399e+00
# TIMESTEP 1930461 / EPSILON 0.9562050000000202 / ACTION [0] / REWARD 0 / Q_MAX 1.234686e+00
# TIMESTEP 1930462 / EPSILON 0.9561100000000202 / ACTION [0] / REWARD 0 / Q_MAX 1.161060e+00
# TIMESTEP 1930463 / EPSILON 0.9560150000000203 / ACTION [0] / REWARD 0 / Q_MAX 1.124047e+00
# TIMESTEP 1930464 / EPSILON 0.9559200000000203 / ACTION [0] / REWARD 0 / Q_MAX 1.092464e+00
# TIMESTEP 1930465 / EPSILON 0.9558250000000204 / ACTION [0] / REWARD 0 / Q_MAX 1.111095e+00
# TIMESTEP 1930466 / EPSILON 0.9557300000000204 / ACTION [0] / REWARD 0 / Q_MAX 1.120148e+00
# TIMESTEP 1930467 / EPSILON 0.9556350000000204 / ACTION [0] / REWARD 0 / Q_MAX 1.149364e+00
# TIMESTEP 1930468 / EPSILON 0.9555400000000205 / ACTION [0] / REWARD 0 / Q_MAX 1.118501e+00
# TIMESTEP 1930469 / EPSILON 0.9554450000000205 / ACTION [0] / REWARD 0 / Q_MAX 1.128520e+00
# TIMESTEP 1930470 / EPSILON 0.9553500000000206 / ACTION [0] / REWARD 0 / Q_MAX 1.102334e+00
# TIMESTEP 1930471 / EPSILON 0.9552550000000206 / ACTION [0] / REWARD 0 / Q_MAX 1.094757e+00
# TIMESTEP 1930472 / EPSILON 0.9551600000000207 / ACTION [1] / REWARD 0 / Q_MAX 1.085164e+00
# TIMESTEP 1930473 / EPSILON 0.9550650000000207 / ACTION [0] / REWARD 0 / Q_MAX 1.091773e+00
# TIMESTEP 1930474 / EPSILON 0.9549700000000207 / ACTION [0] / REWARD 0 / Q_MAX 1.093828e+00
# TIMESTEP 1930475 / EPSILON 0.9548750000000208 / ACTION [0] / REWARD 0 / Q_MAX 1.068128e+00
# TIMESTEP 1930476 / EPSILON 0.9547800000000208 / ACTION [0] / REWARD 0 / Q_MAX 9.688774e-01
# TIMESTEP 1930477 / EPSILON 0.9546850000000209 / ACTION [0] / REWARD 0 / Q_MAX 9.968833e-01
# TIMESTEP 1930478 / EPSILON 0.9545900000000209 / ACTION [0] / REWARD 0 / Q_MAX 9.426209e-01
# TIMESTEP 1930479 / EPSILON 0.954495000000021 / ACTION [0] / REWARD 0 / Q_MAX 9.145536e-01
# TIMESTEP 1930480 / EPSILON 0.954400000000021 / ACTION [0] / REWARD -1 / Q_MAX 8.590817e-01
# TIMESTEP 1930481 / EPSILON 0.954305000000021 / ACTION [0] / REWARD 0 / Q_MAX 1.150531e+00
# TIMESTEP 1930482 / EPSILON 0.9542100000000211 / ACTION [0] / REWARD 0 / Q_MAX 1.232358e+00
# TIMESTEP 1930483 / EPSILON 0.9541150000000211 / ACTION [3] / REWARD 0 / Q_MAX 1.090547e+00
# TIMESTEP 1930484 / EPSILON 0.9540200000000212 / ACTION [2] / REWARD 0 / Q_MAX 1.078552e+00
# TIMESTEP 1930485 / EPSILON 0.9539250000000212 / ACTION [0] / REWARD 0 / Q_MAX 1.091065e+00
# TIMESTEP 1930486 / EPSILON 0.9538300000000213 / ACTION [0] / REWARD 0 / Q_MAX 1.069077e+00
# TIMESTEP 1930487 / EPSILON 0.9537350000000213 / ACTION [0] / REWARD 0 / Q_MAX 1.033402e+00
# TIMESTEP 1930488 / EPSILON 0.9536400000000214 / ACTION [0] / REWARD 0 / Q_MAX 1.049935e+00
# TIMESTEP 1930489 / EPSILON 0.9535450000000214 / ACTION [0] / REWARD 0 / Q_MAX 1.036938e+00
# TIMESTEP 1930490 / EPSILON 0.9534500000000214 / ACTION [0] / REWARD 0 / Q_MAX 9.913275e-01
# TIMESTEP 1930491 / EPSILON 0.9533550000000215 / ACTION [1] / REWARD 0 / Q_MAX 9.641204e-01
# TIMESTEP 1930492 / EPSILON 0.9532600000000215 / ACTION [0] / REWARD 0 / Q_MAX 9.541354e-01
# TIMESTEP 1930493 / EPSILON 0.9531650000000216 / ACTION [4] / REWARD 0 / Q_MAX 1.005621e+00
# TIMESTEP 1930494 / EPSILON 0.9530700000000216 / ACTION [0] / REWARD 0 / Q_MAX 9.425666e-01
# TIMESTEP 1930495 / EPSILON 0.9529750000000217 / ACTION [0] / REWARD 0 / Q_MAX 9.848441e-01
# TIMESTEP 1930496 / EPSILON 0.9528800000000217 / ACTION [0] / REWARD 0 / Q_MAX 9.055749e-01
# TIMESTEP 1930497 / EPSILON 0.9527850000000218 / ACTION [4] / REWARD 0 / Q_MAX 8.678477e-01
# TIMESTEP 1930498 / EPSILON 0.9526900000000218 / ACTION [0] / REWARD 0 / Q_MAX 8.879039e-01
# TIMESTEP 1930499 / EPSILON 0.9525950000000218 / ACTION [0] / REWARD 0 / Q_MAX 8.502695e-01
# TIMESTEP 1930500 / EPSILON 0.9525000000000219 / ACTION [0] / REWARD 0 / Q_MAX 8.533369e-01
# TIMESTEP 1930501 / EPSILON 0.9524050000000219 / ACTION [0] / REWARD 0 / Q_MAX 8.958156e-01
# TIMESTEP 1930502 / EPSILON 0.952310000000022 / ACTION [0] / REWARD 0 / Q_MAX 9.127675e-01
# TIMESTEP 1930503 / EPSILON 0.952215000000022 / ACTION [1] / REWARD 0 / Q_MAX 9.693573e-01
# TIMESTEP 1930504 / EPSILON 0.9521200000000221 / ACTION [0] / REWARD 0 / Q_MAX 9.541786e-01
# TIMESTEP 1930505 / EPSILON 0.9520250000000221 / ACTION [0] / REWARD 0 / Q_MAX 9.661201e-01
# TIMESTEP 1930506 / EPSILON 0.9519300000000221 / ACTION [3] / REWARD 0 / Q_MAX 9.749063e-01
# TIMESTEP 1930507 / EPSILON 0.9518350000000222 / ACTION [0] / REWARD 0 / Q_MAX 9.224881e-01
# TIMESTEP 1930508 / EPSILON 0.9517400000000222 / ACTION [0] / REWARD 0 / Q_MAX 8.710218e-01
# TIMESTEP 1930509 / EPSILON 0.9516450000000223 / ACTION [0] / REWARD 0 / Q_MAX 9.442415e-01
# TIMESTEP 1930510 / EPSILON 0.9515500000000223 / ACTION [4] / REWARD 0 / Q_MAX 9.790212e-01
# TIMESTEP 1930511 / EPSILON 0.9514550000000224 / ACTION [0] / REWARD 0 / Q_MAX 1.001635e+00
# TIMESTEP 1930512 / EPSILON 0.9513600000000224 / ACTION [0] / REWARD 0 / Q_MAX 9.614492e-01
# TIMESTEP 1930513 / EPSILON 0.9512650000000225 / ACTION [0] / REWARD 0 / Q_MAX 9.562670e-01
# TIMESTEP 1930514 / EPSILON 0.9511700000000225 / ACTION [0] / REWARD 0 / Q_MAX 9.270175e-01
# TIMESTEP 1930515 / EPSILON 0.9510750000000225 / ACTION [0] / REWARD 0 / Q_MAX 9.864106e-01
# TIMESTEP 1930516 / EPSILON 0.9509800000000226 / ACTION [2] / REWARD 0 / Q_MAX 9.926585e-01
# TIMESTEP 1930517 / EPSILON 0.9508850000000226 / ACTION [0] / REWARD 0 / Q_MAX 1.008241e+00
# TIMESTEP 1930518 / EPSILON 0.9507900000000227 / ACTION [0] / REWARD 0 / Q_MAX 9.783725e-01
# TIMESTEP 1930519 / EPSILON 0.9506950000000227 / ACTION [0] / REWARD 0 / Q_MAX 1.019596e+00
# TIMESTEP 1930520 / EPSILON 0.9506000000000228 / ACTION [0] / REWARD 0 / Q_MAX 9.760813e-01
# TIMESTEP 1930521 / EPSILON 0.9505050000000228 / ACTION [0] / REWARD 0 / Q_MAX 9.565203e-01
# TIMESTEP 1930522 / EPSILON 0.9504100000000228 / ACTION [0] / REWARD 0 / Q_MAX 9.769264e-01
# TIMESTEP 1930523 / EPSILON 0.9503150000000229 / ACTION [0] / REWARD 0 / Q_MAX 9.533627e-01
# TIMESTEP 1930524 / EPSILON 0.9502200000000229 / ACTION 2 / REWARD 0 / Q_MAX 1.006185e+00
# TIMESTEP 1930525 / EPSILON 0.950125000000023 / ACTION [0] / REWARD 0 / Q_MAX 9.889323e-01
# ...
# TIMESTEP 1934984 / EPSILON 0.5265200000002181 / ACTION [0] / REWARD 0 / Q_MAX 1.878049e+00
# TIMESTEP 1934985 / EPSILON 0.5264250000002182 / ACTION 0 / REWARD 0 / Q_MAX 1.798145e+00
# TIMESTEP 1934986 / EPSILON 0.5263300000002182 / ACTION [0] / REWARD 0 / Q_MAX 1.900961e+00
# TIMESTEP 1934987 / EPSILON 0.5262350000002183 / ACTION [0] / REWARD 0 / Q_MAX 1.950798e+00
# TIMESTEP 1934988 / EPSILON 0.5261400000002183 / ACTION 3 / REWARD 0 / Q_MAX 1.968755e+00
# TIMESTEP 1934989 / EPSILON 0.5260450000002184 / ACTION [0] / REWARD 0 / Q_MAX 2.004391e+00
# TIMESTEP 1934990 / EPSILON 0.5259500000002184 / ACTION 1 / REWARD 0 / Q_MAX 1.985916e+00
# TIMESTEP 1934991 / EPSILON 0.5258550000002185 / ACTION [1] / REWARD 0 / Q_MAX 1.770799e+00
# TIMESTEP 1934992 / EPSILON 0.5257600000002185 / ACTION 1 / REWARD 0 / Q_MAX 1.765898e+00
# TIMESTEP 1934993 / EPSILON 0.5256650000002185 / ACTION 1 / REWARD 0 / Q_MAX 1.794598e+00
# TIMESTEP 1934994 / EPSILON 0.5255700000002186 / ACTION 1 / REWARD 0 / Q_MAX 1.846385e+00
# TIMESTEP 1934995 / EPSILON 0.5254750000002186 / ACTION 4 / REWARD 0 / Q_MAX 1.867165e+00
# TIMESTEP 1934996 / EPSILON 0.5253800000002187 / ACTION [4] / REWARD 0 / Q_MAX 1.991418e+00
# TIMESTEP 1934997 / EPSILON 0.5252850000002187 / ACTION [0] / REWARD 0 / Q_MAX 1.946632e+00
# TIMESTEP 1934998 / EPSILON 0.5251900000002188 / ACTION [4] / REWARD 0 / Q_MAX 1.838559e+00
# TIMESTEP 1934999 / EPSILON 0.5250950000002188 / ACTION [0] / REWARD 0 / Q_MAX 1.862882e+00
# TIMESTEP 1935000 / EPSILON 0.5250000000002188 / ACTION [1] / REWARD 0 / Q_MAX 1.894225e+00
# TIMESTEP 1935001 / EPSILON 0.5249050000002189 / ACTION 0 / REWARD 0 / Q_MAX 1.810279e+00
# TIMESTEP 1935002 / EPSILON 0.5248100000002189 / ACTION 2 / REWARD 0 / Q_MAX 1.843065e+00
# TIMESTEP 1935003 / EPSILON 0.524715000000219 / ACTION [0] / REWARD 0 / Q_MAX 1.888100e+00
# TIMESTEP 1935004 / EPSILON 0.524620000000219 / ACTION [0] / REWARD 0 / Q_MAX 1.836443e+00
# TIMESTEP 1935005 / EPSILON 0.5245250000002191 / ACTION [0] / REWARD 0 / Q_MAX 1.704657e+00
# TIMESTEP 1935006 / EPSILON 0.5244300000002191 / ACTION 4 / REWARD 0 / Q_MAX 1.689452e+00
# TIMESTEP 1935007 / EPSILON 0.5243350000002192 / ACTION 4 / REWARD 0 / Q_MAX 1.746615e+00
# TIMESTEP 1935008 / EPSILON 0.5242400000002192 / ACTION [0] / REWARD 0 / Q_MAX 1.878117e+00
# TIMESTEP 1935009 / EPSILON 0.5241450000002192 / ACTION 3 / REWARD 0 / Q_MAX 1.897496e+00
# TIMESTEP 1935010 / EPSILON 0.5240500000002193 / ACTION 3 / REWARD 0 / Q_MAX 1.949093e+00
# TIMESTEP 1935011 / EPSILON 0.5239550000002193 / ACTION 3 / REWARD 0 / Q_MAX 1.927443e+00
# TIMESTEP 1935012 / EPSILON 0.5238600000002194 / ACTION 3 / REWARD 0 / Q_MAX 1.996854e+00
# TIMESTEP 1935013 / EPSILON 0.5237650000002194 / ACTION 3 / REWARD 0 / Q_MAX 1.989105e+00
# TIMESTEP 1935014 / EPSILON 0.5236700000002195 / ACTION [0] / REWARD 0 / Q_MAX 1.763338e+00
# TIMESTEP 1935015 / EPSILON 0.5235750000002195 / ACTION [0] / REWARD 0 / Q_MAX 1.757157e+00
# TIMESTEP 1935016 / EPSILON 0.5234800000002195 / ACTION [0] / REWARD 0 / Q_MAX 1.602168e+00
# TIMESTEP 1935017 / EPSILON 0.5233850000002196 / ACTION 0 / REWARD 0 / Q_MAX 1.642212e+00
# TIMESTEP 1935018 / EPSILON 0.5232900000002196 / ACTION 2 / REWARD 0 / Q_MAX 1.620251e+00
# TIMESTEP 1935019 / EPSILON 0.5231950000002197 / ACTION 2 / REWARD 0 / Q_MAX 1.651166e+00
# TIMESTEP 1935020 / EPSILON 0.5231000000002197 / ACTION [0] / REWARD 0 / Q_MAX 1.720996e+00
# TIMESTEP 1935021 / EPSILON 0.5230050000002198 / ACTION [0] / REWARD 0 / Q_MAX 1.720285e+00
# TIMESTEP 1935022 / EPSILON 0.5229100000002198 / ACTION [0] / REWARD 0 / Q_MAX 1.642378e+00
# TIMESTEP 1935023 / EPSILON 0.5228150000002199 / ACTION 2 / REWARD 0 / Q_MAX 1.637604e+00
# TIMESTEP 1935024 / EPSILON 0.5227200000002199 / ACTION [0] / REWARD 0 / Q_MAX 1.673186e+00
# TIMESTEP 1935025 / EPSILON 0.5226250000002199 / ACTION 1 / REWARD 0 / Q_MAX 1.591355e+00
# TIMESTEP 1935026 / EPSILON 0.52253000000022 / ACTION [0] / REWARD 0 / Q_MAX 1.666023e+00
# TIMESTEP 1935027 / EPSILON 0.52243500000022 / ACTION 0 / REWARD 0 / Q_MAX 1.640883e+00
# TIMESTEP 1935028 / EPSILON 0.5223400000002201 / ACTION 1 / REWARD 0 / Q_MAX 1.724723e+00
# TIMESTEP 1935029 / EPSILON 0.5222450000002201 / ACTION [0] / REWARD 0 / Q_MAX 1.595045e+00
# TIMESTEP 1935030 / EPSILON 0.5221500000002202 / ACTION 0 / REWARD 0 / Q_MAX 1.655859e+00
# TIMESTEP 1935031 / EPSILON 0.5220550000002202 / ACTION [0] / REWARD 0 / Q_MAX 1.658909e+00
# TIMESTEP 1935032 / EPSILON 0.5219600000002202 / ACTION 0 / REWARD 0 / Q_MAX 1.692008e+00
# TIMESTEP 1935033 / EPSILON 0.5218650000002203 / ACTION [0] / REWARD 0 / Q_MAX 1.657975e+00
# TIMESTEP 1935034 / EPSILON 0.5217700000002203 / ACTION [2] / REWARD 0 / Q_MAX 1.605896e+00
# TIMESTEP 1935035 / EPSILON 0.5216750000002204 / ACTION [0] / REWARD 0 / Q_MAX 1.678675e+00
# TIMESTEP 1935036 / EPSILON 0.5215800000002204 / ACTION [0] / REWARD 0 / Q_MAX 1.625501e+00
# TIMESTEP 1935037 / EPSILON 0.5214850000002205 / ACTION 0 / REWARD 0 / Q_MAX 1.636237e+00
# TIMESTEP 1935038 / EPSILON 0.5213900000002205 / ACTION [0] / REWARD 0 / Q_MAX 1.610201e+00
# TIMESTEP 1935039 / EPSILON 0.5212950000002206 / ACTION 0 / REWARD 0 / Q_MAX 1.509021e+00
# TIMESTEP 1935040 / EPSILON 0.5212000000002206 / ACTION 4 / REWARD 0 / Q_MAX 1.474938e+00
# TIMESTEP 1935041 / EPSILON 0.5211050000002206 / ACTION 1 / REWARD 0 / Q_MAX 1.430516e+00
# TIMESTEP 1935042 / EPSILON 0.5210100000002207 / ACTION [0] / REWARD 0 / Q_MAX 1.500701e+00
# TIMESTEP 1935043 / EPSILON 0.5209150000002207 / ACTION [0] / REWARD 0 / Q_MAX 1.564792e+00
# TIMESTEP 1935044 / EPSILON 0.5208200000002208 / ACTION 1 / REWARD 0 / Q_MAX 1.536006e+00
# TIMESTEP 1935045 / EPSILON 0.5207250000002208 / ACTION 1 / REWARD 0 / Q_MAX 1.553621e+00
# TIMESTEP 1935046 / EPSILON 0.5206300000002209 / ACTION [0] / REWARD 0 / Q_MAX 1.599925e+00
# TIMESTEP 1935047 / EPSILON 0.5205350000002209 / ACTION [0] / REWARD 0 / Q_MAX 1.550659e+00
# TIMESTEP 1935048 / EPSILON 0.520440000000221 / ACTION [1] / REWARD 0 / Q_MAX 1.610994e+00
# TIMESTEP 1935049 / EPSILON 0.520345000000221 / ACTION 0 / REWARD 0 / Q_MAX 1.631061e+00
# TIMESTEP 1935050 / EPSILON 0.520250000000221 / ACTION [0] / REWARD 0 / Q_MAX 1.642964e+00
# TIMESTEP 1935051 / EPSILON 0.5201550000002211 / ACTION [0] / REWARD 0 / Q_MAX 1.561890e+00
# TIMESTEP 1935052 / EPSILON 0.5200600000002211 / ACTION 1 / REWARD 0 / Q_MAX 1.578049e+00
# TIMESTEP 1935053 / EPSILON 0.5199650000002212 / ACTION 0 / REWARD 0 / Q_MAX 1.624045e+00
# TIMESTEP 1935054 / EPSILON 0.5198700000002212 / ACTION [1] / REWARD 0 / Q_MAX 1.595880e+00
# TIMESTEP 1935055 / EPSILON 0.5197750000002213 / ACTION 1 / REWARD 0 / Q_MAX 1.638392e+00
# TIMESTEP 1935056 / EPSILON 0.5196800000002213 / ACTION [0] / REWARD 0 / Q_MAX 1.650207e+00
# TIMESTEP 1935057 / EPSILON 0.5195850000002213 / ACTION [0] / REWARD 0 / Q_MAX 1.622345e+00
# TIMESTEP 1935058 / EPSILON 0.5194900000002214 / ACTION [0] / REWARD 0 / Q_MAX 1.647490e+00
# TIMESTEP 1935059 / EPSILON 0.5193950000002214 / ACTION 1 / REWARD 0 / Q_MAX 1.634508e+00
# TIMESTEP 1935060 / EPSILON 0.5193000000002215 / ACTION [3] / REWARD 0 / Q_MAX 1.600862e+00
# TIMESTEP 1935061 / EPSILON 0.5192050000002215 / ACTION [0] / REWARD 0 / Q_MAX 1.673824e+00
# TIMESTEP 1935062 / EPSILON 0.5191100000002216 / ACTION [0] / REWARD 0 / Q_MAX 1.816326e+00
# TIMESTEP 1935063 / EPSILON 0.5190150000002216 / ACTION [0] / REWARD 0 / Q_MAX 1.742064e+00
# TIMESTEP 1935064 / EPSILON 0.5189200000002216 / ACTION [0] / REWARD 0 / Q_MAX 1.676745e+00
# TIMESTEP 1935065 / EPSILON 0.5188250000002217 / ACTION 1 / REWARD 1 / Q_MAX 1.802917e+00
# TIMESTEP 1935066 / EPSILON 0.5187300000002217 / ACTION 2 / REWARD 0 / Q_MAX 1.793694e+00
# TIMESTEP 1935067 / EPSILON 0.5186350000002218 / ACTION [1] / REWARD 0 / Q_MAX 1.882632e+00
# TIMESTEP 1935068 / EPSILON 0.5185400000002218 / ACTION [0] / REWARD 0 / Q_MAX 1.917944e+00
# TIMESTEP 1935069 / EPSILON 0.5184450000002219 / ACTION [0] / REWARD 0 / Q_MAX 1.986692e+00
# TIMESTEP 1935070 / EPSILON 0.5183500000002219 / ACTION 3 / REWARD 0 / Q_MAX 1.965919e+00
# TIMESTEP 1935071 / EPSILON 0.518255000000222 / ACTION [0] / REWARD 0 / Q_MAX 1.885171e+00
# TIMESTEP 1935072 / EPSILON 0.518160000000222 / ACTION [0] / REWARD 0 / Q_MAX 1.790677e+00
# TIMESTEP 1935073 / EPSILON 0.518065000000222 / ACTION [0] / REWARD 0 / Q_MAX 1.815709e+00
# TIMESTEP 1935074 / EPSILON 0.5179700000002221 / ACTION 3 / REWARD 0 / Q_MAX 1.858199e+00
# TIMESTEP 1935075 / EPSILON 0.5178750000002221 / ACTION [0] / REWARD 0 / Q_MAX 1.931505e+00
# TIMESTEP 1935076 / EPSILON 0.5177800000002222 / ACTION 3 / REWARD 0 / Q_MAX 1.860052e+00
# TIMESTEP 1935077 / EPSILON 0.5176850000002222 / ACTION [0] / REWARD 0 / Q_MAX 1.964114e+00
# TIMESTEP 1935078 / EPSILON 0.5175900000002223 / ACTION 4 / REWARD 0 / Q_MAX 2.030047e+00
# TIMESTEP 1935079 / EPSILON 0.5174950000002223 / ACTION 4 / REWARD 0 / Q_MAX 1.975919e+00
# TIMESTEP 1935080 / EPSILON 0.5174000000002223 / ACTION 4 / REWARD 0 / Q_MAX 2.039714e+00
# TIMESTEP 1935081 / EPSILON 0.5173050000002224 / ACTION [3] / REWARD 0 / Q_MAX 2.021006e+00
# TIMESTEP 1935082 / EPSILON 0.5172100000002224 / ACTION 2 / REWARD 0 / Q_MAX 1.993769e+00
# TIMESTEP 1935083 / EPSILON 0.5171150000002225 / ACTION [0] / REWARD 0 / Q_MAX 2.159138e+00
# TIMESTEP 1935084 / EPSILON 0.5170200000002225 / ACTION [0] / REWARD 0 / Q_MAX 2.041216e+00
# TIMESTEP 1935085 / EPSILON 0.5169250000002226 / ACTION 3 / REWARD 0 / Q_MAX 1.982337e+00
# TIMESTEP 1935086 / EPSILON 0.5168300000002226 / ACTION [0] / REWARD 0 / Q_MAX 2.004420e+00
# TIMESTEP 1935087 / EPSILON 0.5167350000002227 / ACTION 4 / REWARD 0 / Q_MAX 2.086513e+00
# TIMESTEP 1935088 / EPSILON 0.5166400000002227 / ACTION 2 / REWARD 0 / Q_MAX 2.148813e+00
# TIMESTEP 1935089 / EPSILON 0.5165450000002227 / ACTION [0] / REWARD 0 / Q_MAX 2.259210e+00
# TIMESTEP 1935090 / EPSILON 0.5164500000002228 / ACTION [0] / REWARD 0 / Q_MAX 2.280407e+00
# TIMESTEP 1935091 / EPSILON 0.5163550000002228 / ACTION 0 / REWARD 0 / Q_MAX 2.260671e+00
# TIMESTEP 1935092 / EPSILON 0.5162600000002229 / ACTION 4 / REWARD 0 / Q_MAX 2.286766e+00
# TIMESTEP 1935093 / EPSILON 0.5161650000002229 / ACTION 4 / REWARD 0 / Q_MAX 2.200656e+00
# TIMESTEP 1935094 / EPSILON 0.516070000000223 / ACTION [0] / REWARD 0 / Q_MAX 2.007091e+00
# TIMESTEP 1935095 / EPSILON 0.515975000000223 / ACTION 1 / REWARD 0 / Q_MAX 2.076168e+00
# TIMESTEP 1935096 / EPSILON 0.515880000000223 / ACTION [0] / REWARD 0 / Q_MAX 2.070336e+00
# TIMESTEP 1935097 / EPSILON 0.5157850000002231 / ACTION 3 / REWARD 0 / Q_MAX 1.965846e+00
# TIMESTEP 1935098 / EPSILON 0.5156900000002231 / ACTION 3 / REWARD 0 / Q_MAX 1.902363e+00
# TIMESTEP 1935099 / EPSILON 0.5155950000002232 / ACTION 3 / REWARD 0 / Q_MAX 1.984676e+00
# TIMESTEP 1935100 / EPSILON 0.5155000000002232 / ACTION [0] / REWARD 0 / Q_MAX 2.169006e+00
# TIMESTEP 1935101 / EPSILON 0.5154050000002233 / ACTION [0] / REWARD 0 / Q_MAX 2.292874e+00
# TIMESTEP 1935102 / EPSILON 0.5153100000002233 / ACTION [0] / REWARD 0 / Q_MAX 2.438249e+00
# TIMESTEP 1935103 / EPSILON 0.5152150000002234 / ACTION [0] / REWARD 0 / Q_MAX 2.280521e+00
# TIMESTEP 1935104 / EPSILON 0.5151200000002234 / ACTION 0 / REWARD 0 / Q_MAX 2.167860e+00
# TIMESTEP 1935105 / EPSILON 0.5150250000002234 / ACTION 0 / REWARD 0 / Q_MAX 2.264048e+00
# TIMESTEP 1935106 / EPSILON 0.5149300000002235 / ACTION 3 / REWARD 0 / Q_MAX 2.081865e+00
# TIMESTEP 1935107 / EPSILON 0.5148350000002235 / ACTION [0] / REWARD 0 / Q_MAX 2.014641e+00
# TIMESTEP 1935108 / EPSILON 0.5147400000002236 / ACTION [0] / REWARD 0 / Q_MAX 1.883765e+00
# TIMESTEP 1935109 / EPSILON 0.5146450000002236 / ACTION [0] / REWARD 0 / Q_MAX 1.861376e+00
# TIMESTEP 1935110 / EPSILON 0.5145500000002237 / ACTION [0] / REWARD 0 / Q_MAX 1.902347e+00
# TIMESTEP 1935111 / EPSILON 0.5144550000002237 / ACTION 2 / REWARD 0 / Q_MAX 1.952087e+00
# TIMESTEP 1935112 / EPSILON 0.5143600000002237 / ACTION 4 / REWARD 0 / Q_MAX 1.914500e+00
# TIMESTEP 1935113 / EPSILON 0.5142650000002238 / ACTION [0] / REWARD 0 / Q_MAX 1.831159e+00
# TIMESTEP 1935114 / EPSILON 0.5141700000002238 / ACTION [0] / REWARD 0 / Q_MAX 1.826314e+00
# TIMESTEP 1935115 / EPSILON 0.5140750000002239 / ACTION [0] / REWARD 0 / Q_MAX 1.875708e+00
# TIMESTEP 1935116 / EPSILON 0.5139800000002239 / ACTION [0] / REWARD 0 / Q_MAX 1.761963e+00
# TIMESTEP 1935117 / EPSILON 0.513885000000224 / ACTION 0 / REWARD 0 / Q_MAX 1.774059e+00
# TIMESTEP 1935118 / EPSILON 0.513790000000224 / ACTION [0] / REWARD 0 / Q_MAX 1.831885e+00
# TIMESTEP 1935119 / EPSILON 0.5136950000002241 / ACTION 1 / REWARD 0 / Q_MAX 1.924229e+00
# TIMESTEP 1935120 / EPSILON 0.5136000000002241 / ACTION [0] / REWARD 0 / Q_MAX 2.120025e+00
# TIMESTEP 1935121 / EPSILON 0.5135050000002241 / ACTION [0] / REWARD 0 / Q_MAX 2.061038e+00
# TIMESTEP 1935122 / EPSILON 0.5134100000002242 / ACTION 0 / REWARD 0 / Q_MAX 2.085471e+00
# TIMESTEP 1935123 / EPSILON 0.5133150000002242 / ACTION [0] / REWARD 0 / Q_MAX 2.158320e+00
# TIMESTEP 1935124 / EPSILON 0.5132200000002243 / ACTION 0 / REWARD 0 / Q_MAX 2.113905e+00
# TIMESTEP 1935125 / EPSILON 0.5131250000002243 / ACTION 0 / REWARD 0 / Q_MAX 2.066088e+00
# TIMESTEP 1935126 / EPSILON 0.5130300000002244 / ACTION [4] / REWARD 0 / Q_MAX 2.089173e+00
# TIMESTEP 1935127 / EPSILON 0.5129350000002244 / ACTION 3 / REWARD 0 / Q_MAX 2.046297e+00
# TIMESTEP 1935128 / EPSILON 0.5128400000002244 / ACTION [0] / REWARD 0 / Q_MAX 2.042184e+00
# TIMESTEP 1935129 / EPSILON 0.5127450000002245 / ACTION [0] / REWARD 0 / Q_MAX 1.993549e+00
# TIMESTEP 1935130 / EPSILON 0.5126500000002245 / ACTION 3 / REWARD 0 / Q_MAX 2.092320e+00
# TIMESTEP 1935131 / EPSILON 0.5125550000002246 / ACTION 3 / REWARD 0 / Q_MAX 2.054953e+00
# TIMESTEP 1935132 / EPSILON 0.5124600000002246 / ACTION 3 / REWARD 0 / Q_MAX 2.029653e+00
# TIMESTEP 1935133 / EPSILON 0.5123650000002247 / ACTION [0] / REWARD 0 / Q_MAX 2.110471e+00
# TIMESTEP 1935134 / EPSILON 0.5122700000002247 / ACTION 3 / REWARD 0 / Q_MAX 2.021062e+00
# TIMESTEP 1935135 / EPSILON 0.5121750000002248 / ACTION 3 / REWARD 0 / Q_MAX 1.865266e+00
# TIMESTEP 1935136 / EPSILON 0.5120800000002248 / ACTION [0] / REWARD 0 / Q_MAX 1.887422e+00
# TIMESTEP 1935137 / EPSILON 0.5119850000002248 / ACTION [0] / REWARD 0 / Q_MAX 1.723323e+00
# TIMESTEP 1935138 / EPSILON 0.5118900000002249 / ACTION [0] / REWARD 0 / Q_MAX 1.760129e+00
# TIMESTEP 1935139 / EPSILON 0.5117950000002249 / ACTION [2] / REWARD 0 / Q_MAX 1.873077e+00
# TIMESTEP 1935140 / EPSILON 0.511700000000225 / ACTION [0] / REWARD 0 / Q_MAX 1.852672e+00
# TIMESTEP 1935141 / EPSILON 0.511605000000225 / ACTION 3 / REWARD 0 / Q_MAX 1.990289e+00
# TIMESTEP 1935142 / EPSILON 0.5115100000002251 / ACTION 3 / REWARD 0 / Q_MAX 1.963833e+00
# TIMESTEP 1935143 / EPSILON 0.5114150000002251 / ACTION [0] / REWARD 0 / Q_MAX 2.082831e+00
# TIMESTEP 1935144 / EPSILON 0.5113200000002251 / ACTION [0] / REWARD 0 / Q_MAX 2.041712e+00
# TIMESTEP 1935145 / EPSILON 0.5112250000002252 / ACTION [0] / REWARD 0 / Q_MAX 2.027108e+00
# TIMESTEP 1935146 / EPSILON 0.5111300000002252 / ACTION [0] / REWARD 0 / Q_MAX 2.133093e+00
# TIMESTEP 1935147 / EPSILON 0.5110350000002253 / ACTION 2 / REWARD 0 / Q_MAX 2.073458e+00
# TIMESTEP 1935148 / EPSILON 0.5109400000002253 / ACTION [0] / REWARD 0 / Q_MAX 2.016955e+00
# TIMESTEP 1935149 / EPSILON 0.5108450000002254 / ACTION 0 / REWARD 0 / Q_MAX 2.038666e+00
# TIMESTEP 1935150 / EPSILON 0.5107500000002254 / ACTION 0 / REWARD 0 / Q_MAX 2.088614e+00
# TIMESTEP 1935151 / EPSILON 0.5106550000002255 / ACTION 3 / REWARD 0 / Q_MAX 2.079369e+00
# TIMESTEP 1935152 / EPSILON 0.5105600000002255 / ACTION 0 / REWARD 0 / Q_MAX 2.057587e+00
# TIMESTEP 1935153 / EPSILON 0.5104650000002255 / ACTION [0] / REWARD 0 / Q_MAX 2.086265e+00
# TIMESTEP 1935154 / EPSILON 0.5103700000002256 / ACTION [4] / REWARD 0 / Q_MAX 2.244977e+00
# TIMESTEP 1935155 / EPSILON 0.5102750000002256 / ACTION 0 / REWARD 0 / Q_MAX 2.328206e+00
# TIMESTEP 1935156 / EPSILON 0.5101800000002257 / ACTION [0] / REWARD 0 / Q_MAX 2.447351e+00
# TIMESTEP 1935157 / EPSILON 0.5100850000002257 / ACTION [0] / REWARD 0 / Q_MAX 2.289439e+00
# TIMESTEP 1935158 / EPSILON 0.5099900000002258 / ACTION [0] / REWARD 0 / Q_MAX 2.173934e+00
# TIMESTEP 1935159 / EPSILON 0.5098950000002258 / ACTION [0] / REWARD 0 / Q_MAX 2.270471e+00
# TIMESTEP 1935160 / EPSILON 0.5098000000002259 / ACTION [0] / REWARD 0 / Q_MAX 2.086729e+00
